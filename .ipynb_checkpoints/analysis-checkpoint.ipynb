# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import yfinance as yf

data = yf.download("SPY", start="2020-01-01")

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2020-01-02  296.888214  296.906509  294.749767  295.672782  59151200
# 2020-01-03  294.640015  295.764082  293.442850  293.497680  77709700
# 2020-01-06  295.764191  295.846435  292.766677  292.885485  55653900
# 2020-01-07  294.932617  295.672848  294.484803  295.197619  40496400
# 2020-01-08  296.504395  297.719826  294.877711  295.124445  68296000

# %%
data["Close"].plot(figsize=(12,6))

plt.title("SPY Closing Price")
plt.show()
